# %% [markdown]
# # Monte Carlo Stock Price Simulator (GBM)
#
# This notebook loads real stock data, estimates GBM parameters, runs Monte Carlo simulations, and visualizes future price paths.

# %%
#imports and setting up path
import sys
from pathlib import Path

# Add src folder to Python path
root = Path('..').resolve()
sys.path.append(str(root / 'src'))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from data_loader import download_price_data, compute_log_returns
from gbm import estimate_gbm_params
from simulation import simulate_gbm_paths
from plot_utils import plot_sample_paths, plot_final_price_distribution

# %% [markdown]
# ## Load Historical Stock Data
#
# We download daily adjusted close prices using `yfinance`.

# %%
df = download_price_data('AAPL', start='2018-01-01', end='2024-01-01')
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 price
# Date
# 2018-01-02  40.341881
# 2018-01-03  40.334862
# 2018-01-04  40.522217
# 2018-01-05  40.983578
# 2018-01-08  40.831352

# %%
df['price'].plot(figsize=(10, 5), title='AAPL Adjusted Close Price')
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ## Compute Daily Log Returns
#
# Log returns are used to estimate drift and volatility for GBM.

# %%
log_returns = compute_log_returns(df)
log_returns.describe()
# Out:
# count    1508.000000
# mean        0.001030
# std         0.019965
# min        -0.137708
# 25%        -0.008296
# 50%         0.001175
# 75%         0.011825
# max         0.113157
# Name: price, dtype: float64

# %%
sns.histplot(log_returns, bins=50, kde=True)
plt.title('Histogram of Daily Log Returns')
plt.xlabel("Log Return")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Estimate GBM Parameters
#
# We estimate daily drift (mu) and volatility (sigma) from log returns.

# %%
params = estimate_gbm_params(log_returns)
params
# Out:
# {'mu_daily': np.float64(0.0010301473194328707),
#  'sigma_daily': np.float64(0.019965262889157995),
#  'mu_annual': np.float64(0.25959712449708344),
#  'sigma_annual': np.float64(0.3169387227884339)}

# %% [markdown]
# ## Monte Carlo Simulation
#
# We simulate 1000 future price paths over 252 trading days (≈1 year).
# By picking 30 out of 1000 sample price paths, and plotting distribution of all 1000 final prices stimulated, obtaining a right-skewed distribution.

# %%
S0 = df['price'].iloc[-1]
mu = params['mu_daily']
sigma = params['sigma_daily']

paths = simulate_gbm_paths(
    S0=S0,
    mu=mu,
    sigma=sigma,
    n_days=252,
    n_sims=1000,
    random_seed=42
)

paths.shape
# Out:
# (253, 1000)

# %%
plot_sample_paths(paths, n_paths_to_plot=30)
plot_final_price_distribution(paths)

# %% [markdown]
# ## Risk Metrics
#
# We compute expected price, median price, percentiles, and probability of a 20% drop.

# %%
final_prices = paths[-1, :]

expected_price = final_prices.mean()
median_price = np.median(final_prices)
p10 = np.percentile(final_prices, 10)
p90 = np.percentile(final_prices, 90)

threshold = S0 * 0.8
prob_below = np.mean(final_prices < threshold)

expected_price, median_price, p10, p90, prob_below
# Out:
# (np.float64(247.6069889185638),
#  np.float64(236.5487876877345),
#  np.float64(156.094769051706),
#  np.float64(351.7064351716665),
#  np.float64(0.084))

# %% [markdown]
# # Conclusion
#
# In this notebook, we successfully:
#
# - Loaded real historical stock price data
# - Computed daily log returns
# - Estimated GBM drift and volatility parameters
# - Simulated 1000 future price paths using a GBM model
# - Visualized both sample simulated paths and the distribution of final prices
# - Calculated key risk metrics, including percentiles and downside probability
#
# This workflow provides a complete end‑to‑end framework for modelling future stock price behaviour under the Geometric Brownian Motion assumption.
